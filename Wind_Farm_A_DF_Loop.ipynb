# %%
import os
import pandas as pd

# %%
# define directory path and create empty dictionary to hold dataframe keys

directory_path = "/Users/mattzavala/Documents/Data Science Bootcamp/Project 4/CARE_To_Compare/Wind Farm A/datasets"
dataframes = {}

# %%
for filename in os.listdir(directory_path):
    if filename.endswith('.csv'):
        file_path = os.path.join(directory_path, filename)
        try:
            df = pd.read_csv(file_path, sep=";")
            key = os.path.splitext(filename)[0]
            dataframes[key] = df
        except pd.errors.EmptyDataError:
            print(f"Warning: {file_path} is empty and will be skipped.")
        except pd.errors.ParserError:
            print(f"Error: {file_path} does not contain any columns to parse or is malformed.")
        except Exception as e:
            print(f"An unexpected error occurred while reading {file_path}: {e}")


for key, df in dataframes.items():
    print(f"DataFrame for {key}:")
    print(df.head())
# Out:
# Warning: /Users/mattzavala/Documents/Data Science Bootcamp/Project 4/CARE_To_Compare/Wind Farm A/datasets/51.csv is empty and will be skipped.
# DataFrame for 68:
#             time_stamp  asset_id  id train_test  status_type_id  sensor_0_avg  \
# 0  2014-07-29 13:20:00        11   0      train               5          31.0
# 1  2014-07-29 13:30:00        11   1      train               5          31.0
# 2  2014-07-29 13:40:00        11   2      train               5          31.0
# 3  2014-07-29 13:50:00        11   3      train               0          32.0
# 4  2014-07-29 14:00:00        11   4      train               0          32.0
#
#    sensor_1_avg  sensor_2_avg  wind_speed_3_avg  wind_speed_4_avg  ...  \
# 0         152.0          48.7               3.9               3.9  ...
# 1          86.1         150.9               6.0               6.0  ...
# 2         115.2          69.6               6.3               6.3  ...
# 3         129.3         -29.1               6.0               5.9  ...
# 4         137.7          26.4               7.1               6.9  ...
#
#    sensor_47  sensor_48  sensor_49  sensor_50  sensor_51  sensor_52_avg  \
# 0    -2090.0        0.0        0.0    -1185.0    -2090.0            0.4
# 1    -1627.0        0.0        0.0    -1050.0    -1627.0            0.0
# 2    -1624.0        0.0        0.0    -1043.0    -1624.0            0.0
# 3     -212.0    -9540.0        0.0    40124.0    -9753.0            9.5
# 4        0.0   -25215.0        0.0    99360.0   -25215.0           13.1
#
#    sensor_52_max  sensor_52_min  sensor_52_std  sensor_53_avg
# 0            2.6            0.0            0.8           34.0
# 1            0.0            0.0            0.0           34.0
# 2            0.0            0.0            0.0           34.0
# 3           14.0            0.0            4.8           34.0
# 4           14.9           10.8            1.3           35.0
#
# [5 rows x 86 columns]
# DataFrame for 40:
#             time_stamp  asset_id  id train_test  status_type_id  sensor_0_avg  \
# 0  2021-12-30 00:00:00        10   0      train               0          18.0
# 1  2021-12-30 00:10:00        10   1      train               0          18.0
# 2  2021-12-30 00:20:00        10   2      train               0          18.0
# 3  2021-12-30 00:30:00        10   3      train               0          18.0
# 4  2021-12-30 00:40:00        10   4      train               0          18.0
#
#    sensor_1_avg  sensor_2_avg  wind_speed_3_avg  wind_speed_4_avg  ...  \
# 0         220.1           6.1               5.2               5.1  ...
# 1         218.7           4.7               5.7               5.3  ...
# 2         216.7           2.7               6.2               5.8  ...
# 3         197.9         -16.1               6.3               6.2  ...
# 4         217.2           3.2               6.6               6.1  ...
#
#    sensor_47  sensor_48  sensor_49  sensor_50  sensor_51  sensor_52_avg  \
# 0        0.0   -13513.0        0.0    33173.0   -13513.0           11.2
# 1        0.0   -15366.0        0.0    38381.0   -15366.0           11.7
# 2        0.0   -15709.0        0.0    52055.0   -15709.0           12.0
# 3        0.0   -16444.0        0.0    66365.0   -16444.0           12.2
# 4        0.0   -16344.0        0.0    60980.0   -16344.0           12.6
#
#    sensor_52_max  sensor_52_min  sensor_52_std  sensor_53_avg
# 0           12.2           10.9            0.2           19.0
# 1           13.1           10.9            0.4           19.0
# 2           12.8           11.2            0.3           19.0
# 3           13.7           11.2            0.7           19.0
# 4           13.6           11.8            0.4           19.0
#
# [5 rows x 86 columns]
# DataFrame for 69:
#             time_stamp  asset_id  id train_test  status_type_id  sensor_0_avg  \
# 0  2022-09-02 00:50:00        11   0      train               0          26.0
# 1  2022-09-02 01:00:00        11   1      train               0          26.0
# 2  2022-09-02 01:10:00        11   2      train               0          26.0
# 3  2022-09-02 01:20:00        11   3      train               0          26.0
# 4  2022-09-02 01:30:00        11   4      train               0          26.0
#
#    sensor_1_avg  sensor_2_avg  wind_speed_3_avg  wind_speed_4_avg  ...  \
# 0         111.8          -8.1               5.4               5.4  ...
# 1         114.0          -6.0               6.0               5.6  ...
# 2          98.8         -13.5               6.6               6.2  ...
# 3         112.9           0.6               6.4               6.2  ...
# 4         114.6           2.3               6.5               6.2  ...
#
#    sensor_47  sensor_48  sensor_49  sensor_50  sensor_51  sensor_52_avg  \
# 0        0.0   -24431.0        0.0    39576.0   -24431.0           11.4
# 1        0.0   -23599.0        0.0    48194.0   -23599.0           12.2
# 2        0.0   -20851.0        0.0    66092.0   -20851.0           12.7
# 3        0.0   -20686.0        0.0    65045.0   -20686.0           12.4
# 4        0.0   -22726.0        0.0    65003.0   -22726.0           12.5
#
#    sensor_52_max  sensor_52_min  sensor_52_std  sensor_53_avg
# 0           12.9           11.0            0.4           26.0
# 1           14.0           10.8            1.0           26.0
# 2           14.2           11.0            0.9           26.0
# 3           13.9           11.0            0.9           26.0
# 4           14.7           11.0            1.3           26.0
#
# [5 rows x 86 columns]
# DataFrame for 42:
#             time_stamp  asset_id  id train_test  status_type_id  sensor_0_avg  \
# 0  2022-09-08 15:50:00        10   0      train               0          28.0
# 1  2022-09-08 16:00:00        10   1      train               0          28.0
# 2  2022-09-08 16:10:00        10   2      train               0          28.0
# 3  2022-09-08 16:20:00        10   3      train               0          28.0
# 4  2022-09-08 16:30:00        10   4      train               0          27.0
#
#    sensor_1_avg  sensor_2_avg  wind_speed_3_avg  wind_speed_4_avg  ...  \
# 0         298.4          21.7               5.4               5.1  ...
# 1         261.6         -11.9               4.2               4.1  ...
# 2         278.1          23.3               5.1               5.1  ...
# 3         260.2         -19.0               5.4               5.1  ...
# 4         243.5         -38.5               5.1               4.9  ...
#
#    sensor_47  sensor_48  sensor_49  sensor_50  sensor_51  sensor_52_avg  \
# 0        0.0   -13427.0        0.0    34893.0   -13427.0           11.4
# 1     -330.0   -10484.0        0.0    15044.0   -10813.0           11.0
# 2      -70.0   -13573.0        0.0    32280.0   -13644.0           11.4
# 3        0.0   -15221.0        0.0    35256.0   -15221.0           11.5
# 4        0.0   -13350.0        0.0    29621.0   -13350.0           11.4
#
#    sensor_52_max  sensor_52_min  sensor_52_std  sensor_53_avg
# 0           12.6           10.8            0.4           33.0
# 1           11.8           10.2            0.3           33.0
# 2           13.2           10.8            0.5           33.0
# 3           13.1           10.9            0.5           33.0
# 4           13.5           10.8            0.5           33.0
#
# [5 rows x 86 columns]
# DataFrame for 0:
#             time_stamp  asset_id  id train_test  status_type_id  sensor_0_avg  \
# 0  2021-08-03 06:10:00         0   0      train               0          22.0
# 1  2021-08-03 06:20:00         0   1      train               0          22.0
# 2  2021-08-03 06:30:00         0   2      train               0          22.0
# 3  2021-08-03 06:40:00         0   3      train               0          22.0
# 4  2021-08-03 06:50:00         0   4      train               0          22.0
#
#    sensor_1_avg  sensor_2_avg  wind_speed_3_avg  wind_speed_4_avg  ...  \
# 0         302.9         129.4               1.7               1.7  ...
# 1         307.1         133.6               1.7               1.7  ...
# 2         340.6         167.1               0.9               0.9  ...
# 3         124.4         -49.1               1.5               1.5  ...
# 4          66.2        -107.3               1.0               1.0  ...
#
#    sensor_47  sensor_48  sensor_49  sensor_50  sensor_51  sensor_52_avg  \
# 0     -496.0        0.0        0.0    -1280.0     -496.0            0.0
# 1     -490.0        0.0        0.0    -1278.0     -490.0            0.0
# 2     -490.0        0.0        0.0    -1356.0     -490.0            0.0
# 3     -509.0        0.0        0.0    -1274.0     -509.0            0.0
# 4     -499.0        0.0        0.0    -1284.0     -499.0            0.0
#
#    sensor_52_max  sensor_52_min  sensor_52_std  sensor_53_avg
# 0            0.0            0.0            0.0           26.0
# 1            0.0            0.0            0.0           25.0
# 2            0.0            0.0            0.0           25.0
# 3            0.0            0.0            0.0           26.0
# 4            0.0            0.0            0.0           26.0
#
# [5 rows x 86 columns]
# DataFrame for 84:
#             time_stamp  asset_id  id train_test  status_type_id  sensor_0_avg  \
# 0  2021-09-02 15:30:00        13   0      train               0          31.0
# 1  2021-09-02 15:40:00        13   1      train               0          31.0
# 2  2021-09-02 15:50:00        13   2      train               0          31.0
# 3  2021-09-02 16:00:00        13   3      train               0          31.0
# 4  2021-09-02 16:10:00        13   4      train               0          31.0
#
#    sensor_1_avg  sensor_2_avg  wind_speed_3_avg  wind_speed_4_avg  ...  \
# 0          81.6          -2.2              13.5              13.4  ...
# 1          89.8          13.3              13.1              12.8  ...
# 2          68.7          -6.7              13.3              13.2  ...
# 3          76.2          -6.6              13.2              13.0  ...
# 4          70.5          -5.7              12.4              12.3  ...
#
#    sensor_47  sensor_48  sensor_49  sensor_50  sensor_51  sensor_52_avg  \
# 0        0.0   -37991.0        0.0   332506.0   -37991.0           14.9
# 1        0.0   -37765.0        0.0   331285.0   -37765.0           14.9
# 2        0.0   -37519.0        0.0   332975.0   -37519.0           14.9
# 3        0.0   -37775.0        0.0   332570.0   -37775.0           14.9
# 4        0.0   -37969.0        0.0   331832.0   -37969.0           14.9
#
#    sensor_52_max  sensor_52_min  sensor_52_std  sensor_53_avg
# 0           15.7           14.3            0.2           34.0
# 1           15.7           14.4            0.2           34.0
# 2           15.9           14.3            0.2           34.0
# 3           15.6           14.4            0.2           34.0
# 4           15.6           14.4            0.2           34.0
#
# [5 rows x 86 columns]
# DataFrame for 92:
#             time_stamp  asset_id  id train_test  status_type_id  sensor_0_avg  \
# 0  2019-04-04 02:30:00        11   0      train               5          15.0
# 1  2019-04-04 02:40:00        11   1      train               5          15.0
# 2  2019-04-04 02:50:00        11   2      train               5          15.0
# 3  2019-04-04 03:00:00        11   3      train               5          15.0
# 4  2019-04-04 03:10:00        11   4      train               5          15.0
#
#    sensor_1_avg  sensor_2_avg  wind_speed_3_avg  wind_speed_4_avg  ...  \
# 0         257.0          -1.8               2.7               2.7  ...
# 1         267.3          13.4               2.6               2.6  ...
# 2         280.9          27.0               3.0               3.0  ...
# 3         256.5           6.8               2.8               2.8  ...
# 4         260.2           7.4               3.4               3.4  ...
#
#    sensor_47  sensor_48  sensor_49  sensor_50  sensor_51  sensor_52_avg  \
# 0     -375.0        0.0        0.0     -885.0     -375.0            2.0
# 1     -226.0        0.0        0.0     -822.0     -226.0            1.9
# 2     -360.0        0.0        0.0     -884.0     -360.0            2.2
# 3     -356.0        0.0        0.0     -869.0     -356.0            2.2
# 4      -13.0      771.0        0.0       20.0      759.0            4.5
#
#    sensor_52_max  sensor_52_min  sensor_52_std  sensor_53_avg
# 0            2.2            1.6            0.1           17.0
# 1            2.2            1.5            0.2           17.0
# 2            2.6            1.7            0.2           17.0
# 3            2.6            1.8            0.2           17.0
# 4           12.2            2.1            3.5           17.0
#
# [5 rows x 86 columns]
# DataFrame for 3:
#             time_stamp  asset_id  id train_test  status_type_id  sensor_0_avg  \
# 0  2019-04-27 03:00:00        10   0      train               0          18.0
# 1  2019-04-27 03:10:00        10   1      train               0          18.0
# 2  2019-04-27 03:20:00        10   2      train               0          18.0
# 3  2019-04-27 03:30:00        10   3      train               0          18.0
# 4  2019-04-27 03:40:00        10   4      train               5          18.0
#
#    sensor_1_avg  sensor_2_avg  wind_speed_3_avg  wind_speed_4_avg  ...  \
# 0          75.0          89.9               1.0               1.0  ...
# 1         154.6         169.5               1.5               1.5  ...
# 2         248.8         -96.3               1.3               1.3  ...
# 3         234.7        -110.4               1.6               1.6  ...
# 4         334.6         -10.5               2.0               2.0  ...
#
#    sensor_47  sensor_48  sensor_49  sensor_50  sensor_51  sensor_52_avg  \
# 0    -1741.0        0.0        0.0    -1280.0    -1741.0            0.0
# 1    -1724.0        0.0        0.0    -1280.0    -1724.0            0.0
# 2    -1733.0        0.0        0.0    -1268.0    -1733.0            0.0
# 3    -1740.0        0.0        0.0    -1271.0    -1740.0            0.0
# 4    -1756.0        0.0        0.0    -1294.0    -1756.0            0.0
#
#    sensor_52_max  sensor_52_min  sensor_52_std  sensor_53_avg
# 0            0.0            0.0            0.0           19.0
# 1            0.0            0.0            0.0           19.0
# 2            0.0            0.0            0.0           19.0
# 3            0.0            0.0            0.0           19.0
# 4            0.0            0.0            0.0           19.0
#
# [5 rows x 86 columns]
# DataFrame for 45:
#             time_stamp  asset_id  id train_test  status_type_id  sensor_0_avg  \
# 0  2019-04-16 18:10:00        13   0      train               0          18.0
# 1  2019-04-16 18:20:00        13   1      train               0          18.0
# 2  2019-04-16 18:30:00        13   2      train               0          18.0
# 3  2019-04-16 18:40:00        13   3      train               0          18.0
# 4  2019-04-16 18:50:00        13   4      train               0          18.0
#
#    sensor_1_avg  sensor_2_avg  wind_speed_3_avg  wind_speed_4_avg  ...  \
# 0         216.1         -15.7              10.0              10.2  ...
# 1         240.3           7.4               9.8               9.9  ...
# 2         223.8          -9.1              10.5              10.6  ...
# 3         216.8          -9.1               9.4               9.6  ...
# 4         239.8           5.1               8.8               9.1  ...
#
#    sensor_47  sensor_48  sensor_49  sensor_50  sensor_51  sensor_52_avg  \
# 0        0.0   -32680.0        0.0   272184.0   -32680.0           14.6
# 1        0.0   -32382.0        0.0   258030.0   -32382.0           14.6
# 2        0.0   -30910.0        0.0   293642.0   -30910.0           14.7
# 3        0.0   -28154.0        0.0   245039.0   -28154.0           14.5
# 4        0.0   -29189.0        0.0   211204.0   -29189.0           14.4
#
#    sensor_52_max  sensor_52_min  sensor_52_std  sensor_53_avg
# 0           15.4           13.5            0.3           23.0
# 1           15.3           13.7            0.3           22.0
# 2           15.4           14.2            0.2           22.0
# 3           15.3           13.5            0.3           22.0
# 4           15.0           12.7            0.4           21.0
#
# [5 rows x 86 columns]
# DataFrame for 22:
#             time_stamp  asset_id  id train_test  status_type_id  sensor_0_avg  \
# 0  2020-08-11 09:50:00        21   0      train               0          25.0
# 1  2020-08-11 10:00:00        21   1      train               0          25.0
# 2  2020-08-11 10:10:00        21   2      train               0          25.0
# 3  2020-08-11 10:20:00        21   3      train               0          25.0
# 4  2020-08-11 10:30:00        21   4      train               0          26.0
#
#    sensor_1_avg  sensor_2_avg  wind_speed_3_avg  wind_speed_4_avg  ...  \
# 0         105.9           7.5              18.4              17.2  ...
# 1         107.9           9.5              18.6              17.5  ...
# 2         124.8          26.4              18.3              17.2  ...
# 3         114.1          15.8              18.8              17.6  ...
# 4         100.9           2.5              18.7              17.5  ...
#
#    sensor_47  sensor_48  sensor_49  sensor_50  sensor_51  sensor_52_avg  \
# 0        0.0   -36274.0        0.0   333234.0   -36274.0           14.9
# 1        0.0   -36607.0        0.0   333268.0   -36607.0           14.9
# 2        0.0   -36297.0        0.0   333256.0   -36297.0           14.9
# 3        0.0   -36063.0        0.0   333287.0   -36063.0           14.9
# 4        0.0   -35916.0        0.0   333223.0   -35916.0           14.9
#
#    sensor_52_max  sensor_52_min  sensor_52_std  sensor_53_avg
# 0           15.7           13.9            0.3           29.0
# 1           15.8           14.1            0.3           29.0
# 2           16.2           14.1            0.3           30.0
# 3           15.8           14.2            0.3           30.0
# 4           15.8           14.0            0.3           30.0
#
# [5 rows x 86 columns]
# DataFrame for 25:
#             time_stamp  asset_id  id train_test  status_type_id  sensor_0_avg  \
# 0  2022-05-22 06:50:00        11   0      train               5          18.0
# 1  2022-05-22 07:00:00        11   1      train               5          18.0
# 2  2022-05-22 07:10:00        11   2      train               5          18.0
# 3  2022-05-22 07:20:00        11   3      train               5          18.0
# 4  2022-05-22 07:30:00        11   4      train               5          18.0
#
#    sensor_1_avg  sensor_2_avg  wind_speed_3_avg  wind_speed_4_avg  ...  \
# 0         161.3         156.2               2.4               2.4  ...
# 1         172.3         167.1               2.8               2.8  ...
# 2         173.0          41.0               3.1               3.1  ...
# 3         168.4           5.6               2.4               2.4  ...
# 4         155.4         -18.6               2.3               2.3  ...
#
#    sensor_47  sensor_48  sensor_49  sensor_50  sensor_51  sensor_52_avg  \
# 0     -130.0        0.0        0.0     -682.0     -130.0            0.0
# 1     -972.0        0.0        0.0     -996.0     -972.0            0.0
# 2     -542.0        0.0        0.0     -849.0     -542.0            2.0
# 3     -327.0        0.0        0.0     -781.0     -327.0            1.5
# 4     -253.0        0.0        0.0     -748.0     -253.0            1.2
#
#    sensor_52_max  sensor_52_min  sensor_52_std  sensor_53_avg
# 0            0.0            0.0            0.0           19.0
# 1            0.0            0.0            0.0           19.0
# 2            2.2            0.0            0.3           20.0
# 3            2.1            0.0            0.5           20.0
# 4            1.9            0.0            0.8           20.0
#
# [5 rows x 86 columns]
# DataFrame for 24:
#             time_stamp  asset_id  id train_test  status_type_id  sensor_0_avg  \
# 0  2022-04-23 15:00:00         0   0      train               0          25.0
# 1  2022-04-23 15:10:00         0   1      train               0          25.0
# 2  2022-04-23 15:20:00         0   2      train               0          26.0
# 3  2022-04-23 15:30:00         0   3      train               0          26.0
# 4  2022-04-23 15:40:00         0   4      train               0          26.0
#
#    sensor_1_avg  sensor_2_avg  wind_speed_3_avg  wind_speed_4_avg  ...  \
# 0         317.8          -1.9               3.2               3.2  ...
# 1           2.5          15.5               4.0               3.9  ...
# 2          17.3          13.9               3.1               2.9  ...
# 3          47.1          67.8               4.2               4.3  ...
# 4         329.3          -9.6               3.1               3.0  ...
#
#    sensor_47  sensor_48  sensor_49  sensor_50  sensor_51  sensor_52_avg  \
# 0    -1086.0     1432.0        0.0     2739.0      346.0            3.6
# 1     -279.0    -7125.0        0.0     9871.0    -7403.0           11.0
# 2    -2146.0      649.0        0.0     -489.0    -1496.0            6.0
# 3     -607.0    -6955.0        0.0    15209.0    -7562.0            9.2
# 4    -2353.0    -1734.0        0.0     -989.0    -4087.0            5.3
#
#    sensor_52_max  sensor_52_min  sensor_52_std  sensor_53_avg
# 0           12.8            1.6            3.5           28.0
# 1           12.1           10.0            0.3           28.0
# 2           11.2            0.0            4.7           28.0
# 3           12.7            0.0            3.7           28.0
# 4           11.2            0.0            4.6           29.0
#
# [5 rows x 86 columns]
# DataFrame for 26:
#             time_stamp  asset_id  id train_test  status_type_id  sensor_0_avg  \
# 0  2019-10-12 10:20:00         0   0      train               0          17.0
# 1  2019-10-12 10:30:00         0   1      train               0          17.0
# 2  2019-10-12 10:40:00         0   2      train               0          17.0
# 3  2019-10-12 10:50:00         0   3      train               0          18.0
# 4  2019-10-12 11:00:00         0   4      train               0          17.0
#
#    sensor_1_avg  sensor_2_avg  wind_speed_3_avg  wind_speed_4_avg  ...  \
# 0         184.0         -10.8              13.2              13.4  ...
# 1         188.3          -6.2              13.6              14.0  ...
# 2         186.0          -8.4              12.7              13.2  ...
# 3         190.8          -3.7              13.4              13.8  ...
# 4         205.0          10.5              12.7              12.9  ...
#
#    sensor_47  sensor_48  sensor_49  sensor_50  sensor_51  sensor_52_avg  \
# 0        0.0   -36842.0        0.0   333190.0   -36842.0           14.9
# 1        0.0   -36493.0        0.0   333266.0   -36493.0           14.9
# 2        0.0   -36213.0        0.0   332999.0   -36213.0           14.9
# 3        0.0   -36397.0        0.0   333473.0   -36397.0           14.9
# 4        0.0   -35976.0        0.0   332011.0   -35976.0           14.9
#
#    sensor_52_max  sensor_52_min  sensor_52_std  sensor_53_avg
# 0           15.7           14.0            0.2           19.0
# 1           15.4           14.1            0.2           19.0
# 2           15.6           14.3            0.2           19.0
# 3           15.7           14.2            0.2           19.0
# 4           15.5           14.5            0.2           19.0
#
# [5 rows x 86 columns]
# DataFrame for 17:
#             time_stamp  asset_id  id train_test  status_type_id  sensor_0_avg  \
# 0  2014-11-01 15:20:00        10   0      train               0          23.0
# 1  2014-11-01 15:30:00        10   1      train               0          23.0
# 2  2014-11-01 15:40:00        10   2      train               0          23.0
# 3  2014-11-01 15:50:00        10   3      train               0          23.0
# 4  2014-11-01 16:00:00        10   4      train               0          23.0
#
#    sensor_1_avg  sensor_2_avg  wind_speed_3_avg  wind_speed_4_avg  ...  \
# 0          91.8         -23.0              11.9              11.0  ...
# 1         113.6           6.8              11.3              10.7  ...
# 2         120.8          14.0              12.0              11.5  ...
# 3         103.1          -3.6              11.1              10.6  ...
# 4         106.3          -0.4              11.1              10.6  ...
#
#    sensor_47  sensor_48  sensor_49  sensor_50  sensor_51  sensor_52_avg  \
# 0        0.0   -36385.0        0.0   308143.0   -36385.0           14.8
# 1        0.0   -36130.0        0.0   290647.0   -36130.0           14.7
# 2        0.0   -36544.0        0.0   316901.0   -36544.0           14.8
# 3        0.0   -36584.0        0.0   293093.0   -36584.0           14.7
# 4        0.0   -36258.0        0.0   289156.0   -36258.0           14.7
#
#    sensor_52_max  sensor_52_min  sensor_52_std  sensor_53_avg
# 0           15.4           13.8            0.2           27.0
# 1           15.3           13.7            0.2           27.0
# 2           15.5           14.5            0.2           26.0
# 3           15.4           14.1            0.2           26.0
# 4           15.3           13.5            0.2           26.0
#
# [5 rows x 86 columns]
# DataFrame for 14:
#             time_stamp  asset_id  id train_test  status_type_id  sensor_0_avg  \
# 0  2021-03-02 14:00:00        13   0      train               4          14.0
# 1  2021-03-02 14:10:00        13   1      train               4          14.0
# 2  2021-03-02 14:40:00        13   2      train               4          14.0
# 3  2021-03-02 14:50:00        13   3      train               4          14.0
# 4  2021-03-02 15:00:00        13   4      train               4          14.0
#
#    sensor_1_avg  sensor_2_avg  wind_speed_3_avg  wind_speed_4_avg  ...  \
# 0         273.7         -46.4               6.0               6.0  ...
# 1         259.5         -60.6               6.0               0.0  ...
# 2         251.8         -68.3               5.5               0.3  ...
# 3         263.3         -56.7               5.4               5.4  ...
# 4         271.5          24.2               4.6               4.6  ...
#
#    sensor_47  sensor_48  sensor_49  sensor_50  sensor_51  sensor_52_avg  \
# 0      210.0        0.0        0.0     -469.0      210.0            0.0
# 1      -73.0        0.0        0.0     -169.0      -73.0            0.0
# 2       64.0        0.0        0.0     -364.0       64.0            0.0
# 3    -1132.0       -2.0        0.0    -1703.0    -1134.0            1.4
# 4       99.0        0.0        0.0     -640.0       99.0            0.0
#
#    sensor_52_max  sensor_52_min  sensor_52_std  sensor_53_avg
# 0            0.0            0.0            0.0           17.0
# 1            0.0            0.0            0.0           18.0
# 2            0.0            0.0            0.0           18.0
# 3           12.6            0.0            3.0           18.0
# 4            0.0            0.0            0.0           18.0
#
# [5 rows x 86 columns]
# DataFrame for 10:
#             time_stamp  asset_id  id train_test  status_type_id  sensor_0_avg  \
# 0  2013-10-10 08:40:00        10   0      train               0          20.0
# 1  2013-10-10 08:50:00        10   1      train               0          20.0
# 2  2013-10-10 09:00:00        10   2      train               0          20.0
# 3  2013-10-10 09:10:00        10   3      train               0          20.0
# 4  2013-10-10 09:20:00        10   4      train               0          20.0
#
#    sensor_1_avg  sensor_2_avg  wind_speed_3_avg  wind_speed_4_avg  ...  \
# 0         265.7          19.4               2.6               2.6  ...
# 1         244.9         -11.8               2.6               2.6  ...
# 2         299.5          42.7               2.5               2.5  ...
# 3         280.2          23.5               2.5               2.5  ...
# 4         281.1          24.3               2.7               2.7  ...
#
#    sensor_47  sensor_48  sensor_49  sensor_50  sensor_51  sensor_52_avg  \
# 0    -1946.0        0.0        0.0    -1371.0    -1946.0            1.8
# 1    -1850.0        0.0        0.0    -1309.0    -1850.0            1.8
# 2    -1851.0        0.0        0.0    -1349.0    -1851.0            1.6
# 3    -1824.0        0.0        0.0    -1326.0    -1824.0            1.7
# 4    -1838.0        0.0        0.0    -1324.0    -1838.0            1.9
#
#    sensor_52_max  sensor_52_min  sensor_52_std  sensor_53_avg
# 0            2.0            0.0            0.2           23.0
# 1            2.0            1.5            0.1           23.0
# 2            2.0            0.0            0.7           23.0
# 3            1.9            1.5            0.1           23.0
# 4            2.1            1.8            0.1           23.0
#
# [5 rows x 86 columns]
# DataFrame for 38:
#             time_stamp  asset_id  id train_test  status_type_id  sensor_0_avg  \
# 0  2020-06-27 15:40:00        13   0      train               0          28.0
# 1  2020-06-27 15:50:00        13   1      train               0          28.0
# 2  2020-06-27 16:00:00        13   2      train               0          28.0
# 3  2020-06-27 16:10:00        13   3      train               0          28.0
# 4  2020-06-27 16:20:00        13   4      train               0          27.0
#
#    sensor_1_avg  sensor_2_avg  wind_speed_3_avg  wind_speed_4_avg  ...  \
# 0          95.7         -21.4               5.7               5.9  ...
# 1          95.1         -15.1               7.2               7.4  ...
# 2         118.3           7.7               6.2               6.3  ...
# 3         124.7           3.3               6.6               6.4  ...
# 4         104.4          -0.8               7.3               7.2  ...
#
#    sensor_47  sensor_48  sensor_49  sensor_50  sensor_51  sensor_52_avg  \
# 0        0.0   -20545.0        0.0    64646.0   -20545.0           12.3
# 1        0.0   -22803.0        0.0   120042.0   -22803.0           13.3
# 2        0.0   -20781.0        0.0    76563.0   -20781.0           12.5
# 3        0.0   -22279.0        0.0    75697.0   -22279.0           12.7
# 4        0.0   -23700.0        0.0   104784.0   -23700.0           13.5
#
#    sensor_52_max  sensor_52_min  sensor_52_std  sensor_53_avg
# 0           14.6           10.6            1.2           30.0
# 1           14.9           10.7            1.2           30.0
# 2           14.8           10.8            1.4           30.0
# 3           14.7           11.0            1.1           30.0
# 4           14.8           11.3            0.8           30.0
#
# [5 rows x 86 columns]
# DataFrame for 13:
#             time_stamp  asset_id  id train_test  status_type_id  sensor_0_avg  \
# 0  2022-04-29 13:20:00        21   0      train               5          22.0
# 1  2022-04-29 13:30:00        21   1      train               5          23.0
# 2  2022-04-29 13:40:00        21   2      train               0          24.0
# 3  2022-04-29 13:50:00        21   3      train               0          24.0
# 4  2022-04-29 14:00:00        21   4      train               0          25.0
#
#    sensor_1_avg  sensor_2_avg  wind_speed_3_avg  wind_speed_4_avg  ...  \
# 0          57.4         -75.5               2.5               2.5  ...
# 1          93.0          31.4               2.2               2.2  ...
# 2         119.9          58.3               1.7               1.7  ...
# 3          65.2           3.6               1.2               1.2  ...
# 4          53.7          -7.8               1.5               1.5  ...
#
#    sensor_47  sensor_48  sensor_49  sensor_50  sensor_51  sensor_52_avg  \
# 0    -1460.0        0.0        0.0    -1690.0    -1460.0            0.3
# 1    -1088.0        0.0        0.0    -1518.0    -1088.0            0.8
# 2     -747.0        0.0        0.0    -1119.0     -747.0            0.0
# 3     -612.0        0.0        0.0     -939.0     -612.0            0.0
# 4     -294.0        0.0        0.0     -740.0     -294.0            0.0
#
#    sensor_52_max  sensor_52_min  sensor_52_std  sensor_53_avg
# 0            1.9            0.0            0.6           27.0
# 1            2.3            0.0            0.9           27.0
# 2            0.0            0.0            0.0           27.0
# 3            0.0            0.0            0.0           27.0
# 4            0.0            0.0            0.0           27.0
#
# [5 rows x 86 columns]
# DataFrame for 73:
#             time_stamp  asset_id  id train_test  status_type_id  sensor_0_avg  \
# 0  2022-06-06 11:40:00         0   0      train               0          26.0
# 1  2022-06-06 11:50:00         0   1      train               0          26.0
# 2  2022-06-06 12:00:00         0   2      train               0          26.0
# 3  2022-06-06 12:10:00         0   3      train               0          26.0
# 4  2022-06-06 12:20:00         0   4      train               0          26.0
#
#    sensor_1_avg  sensor_2_avg  wind_speed_3_avg  wind_speed_4_avg  ...  \
# 0          79.6          -7.2               9.4               9.3  ...
# 1          72.7         -14.2               9.8               9.8  ...
# 2          75.4         -11.4              10.3              10.0  ...
# 3          97.7          10.4              10.9              10.6  ...
# 4          96.8          16.9              10.1              10.0  ...
#
#    sensor_47  sensor_48  sensor_49  sensor_50  sensor_51  sensor_52_avg  \
# 0        0.0   -29207.0        0.0   226986.0   -29207.0           14.5
# 1        0.0   -29154.0        0.0   251915.0   -29154.0           14.6
# 2        0.0   -30859.0        0.0   269068.0   -30859.0           14.7
# 3        0.0   -32139.0        0.0   299279.0   -32139.0           14.8
# 4        0.0   -31263.0        0.0   267141.0   -31263.0           14.7
#
#    sensor_52_max  sensor_52_min  sensor_52_std  sensor_53_avg
# 0           15.0           13.3            0.3           31.0
# 1           15.1           14.0            0.2           31.0
# 2           15.1           14.2            0.2           31.0
# 3           15.3           14.4            0.1           31.0
# 4           15.1           14.1            0.2           31.0
#
# [5 rows x 86 columns]
# DataFrame for 72:
#             time_stamp  asset_id  id train_test  status_type_id  sensor_0_avg  \
# 0  2020-10-06 08:40:00        21   0      train               5          18.0
# 1  2020-10-06 08:50:00        21   1      train               0          18.0
# 2  2020-10-06 09:00:00        21   2      train               0          18.0
# 3  2020-10-06 09:10:00        21   3      train               0          18.0
# 4  2020-10-06 09:20:00        21   4      train               0          19.0
#
#    sensor_1_avg  sensor_2_avg  wind_speed_3_avg  wind_speed_4_avg  ...  \
# 0         171.6          61.3               2.1               2.1  ...
# 1         166.0          55.7               1.6               1.6  ...
# 2         179.5          69.2               1.7               1.7  ...
# 3         168.3          58.0               1.8               1.8  ...
# 4         173.6          63.3               1.7               1.7  ...
#
#    sensor_47  sensor_48  sensor_49  sensor_50  sensor_51  sensor_52_avg  \
# 0     -669.0        0.0        0.0     -728.0     -669.0            0.0
# 1     -656.0        0.0        0.0     -723.0     -656.0            0.0
# 2     -668.0        0.0        0.0     -742.0     -668.0            0.0
# 3     -652.0        0.0        0.0     -719.0     -652.0            0.0
# 4     -658.0        0.0        0.0     -725.0     -658.0            0.0
#
#    sensor_52_max  sensor_52_min  sensor_52_std  sensor_53_avg
# 0            0.0            0.0            0.0           20.0
# 1            0.0            0.0            0.0           20.0
# 2            0.0            0.0            0.0           20.0
# 3            0.0            0.0            0.0           20.0
# 4            0.0            0.0            0.0           20.0
#
# [5 rows x 86 columns]
# DataFrame for 71:
#             time_stamp  asset_id  id train_test  status_type_id  sensor_0_avg  \
# 0  2017-12-31 00:00:00         0   0      train               0          18.0
# 1  2017-12-31 00:10:00         0   1      train               0          18.0
# 2  2017-12-31 00:20:00         0   2      train               0          18.0
# 3  2017-12-31 00:30:00         0   3      train               0          18.0
# 4  2017-12-31 00:40:00         0   4      train               0          18.0
#
#    sensor_1_avg  sensor_2_avg  wind_speed_3_avg  wind_speed_4_avg  ...  \
# 0         178.7         -18.6               4.1               4.4  ...
# 1         191.8         -12.2               4.1               4.3  ...
# 2         213.8          16.8               4.1               4.4  ...
# 3         199.3          -4.6               4.4               4.6  ...
# 4         199.9          -4.0               5.5               5.7  ...
#
#    sensor_47  sensor_48  sensor_49  sensor_50  sensor_51  sensor_52_avg  \
# 0        0.0   -11991.0        0.0    18831.0   -11991.0           11.1
# 1        0.0   -14360.0        0.0    15865.0   -14360.0           11.1
# 2        0.0   -15524.0        0.0    17244.0   -15524.0           11.1
# 3        0.0   -16444.0        0.0    22284.0   -16444.0           11.2
# 4        0.0   -16353.0        0.0    49587.0   -16353.0           11.4
#
#    sensor_52_max  sensor_52_min  sensor_52_std  sensor_53_avg
# 0           11.7           10.9            0.1           20.0
# 1           11.3           10.9            0.1           20.0
# 2           11.3           10.9            0.1           20.0
# 3           12.4           10.9            0.2           20.0
# 4           12.1           10.9            0.3           20.0
#
# [5 rows x 86 columns]

# %%
for key, df in dataframes.items():
    # Check for null values in each DataFrame
    null_rows = df[df.isnull().any(axis=1)]
    
    # Print information about null rows
    if not null_rows.empty:
        print(f"DataFrame for {key} contains null values in the following rows:")
        print(null_rows)
    else:
        print(f"DataFrame for {key} does not contain any null values.")
# Out:
# DataFrame for 68 does not contain any null values.
# DataFrame for 40 contains null values in the following rows:
#                 time_stamp  asset_id     id  train_test  status_type_id  \
# 55632  2023-01-22 19:00:00        10  55632  prediction               0
# 55633  2023-01-22 19:40:00        10  55633  prediction               0
#
#        sensor_0_avg  sensor_1_avg  sensor_2_avg  wind_speed_3_avg  \
# 55632          12.0         301.1           2.6               3.5
# 55633          11.0         283.9          -9.0               4.0
#
#        wind_speed_4_avg  ...  sensor_47  sensor_48  sensor_49  sensor_50  \
# 55632               3.5  ...     -635.0     -270.0        0.0    -1043.0
# 55633               3.7  ...     -510.0        3.0        0.0     -180.0
#
#        sensor_51  sensor_52_avg  sensor_52_max  sensor_52_min  sensor_52_std  \
# 55632     -905.0            5.4           13.0            0.0            4.6
# 55633     -507.0            5.1           12.7            0.0            4.3
#
#        sensor_53_avg
# 55632           16.0
# 55633           15.0
#
# [2 rows x 86 columns]
# DataFrame for 69 contains null values in the following rows:
#                 time_stamp  asset_id     id train_test  status_type_id  \
# 49863  2023-08-16 15:30:00        11  49863      train               0
#
#        sensor_0_avg  sensor_1_avg  sensor_2_avg  wind_speed_3_avg  \
# 49863          33.0         119.9           8.3               8.6
#
#        wind_speed_4_avg  ...  sensor_47  sensor_48  sensor_49  sensor_50  \
# 49863               8.2  ...        0.0   -30208.0        0.0   165420.0
#
#        sensor_51  sensor_52_avg  sensor_52_max  sensor_52_min  sensor_52_std  \
# 49863   -30208.0           14.1           15.0           10.8            1.1
#
#        sensor_53_avg
# 49863           35.0
#
# [1 rows x 86 columns]
# DataFrame for 42 contains null values in the following rows:
#                 time_stamp  asset_id     id train_test  status_type_id  \
# 19539  2023-01-22 19:00:00        10  19539      train               5
# 19540  2023-01-22 19:40:00        10  19540      train               5
# 48973  2023-08-16 12:20:00        10  48973      train               0
#
#        sensor_0_avg  sensor_1_avg  sensor_2_avg  wind_speed_3_avg  \
# 19539          12.0         301.1           2.6               3.5
# 19540          11.0         283.9          -9.0               4.0
# 48973          30.0         175.7          43.1               6.4
#
#        wind_speed_4_avg  ...  sensor_47  sensor_48  sensor_49  sensor_50  \
# 19539               3.5  ...     -635.0     -270.0        0.0    -1043.0
# 19540               3.7  ...     -510.0        3.0        0.0     -180.0
# 48973               6.2  ...     -834.0   -18886.0        0.0    49351.0
#
#        sensor_51  sensor_52_avg  sensor_52_max  sensor_52_min  sensor_52_std  \
# 19539     -905.0            5.4           13.0            0.0            4.6
# 19540     -507.0            5.1           12.7            0.0            4.3
# 48973   -19720.0            9.1           14.5            0.0            5.8
#
#        sensor_53_avg
# 19539           16.0
# 19540           15.0
# 48973           36.0
#
# [3 rows x 86 columns]
# DataFrame for 0 contains null values in the following rows:
#                 time_stamp  asset_id     id  train_test  status_type_id  \
# 54051  2022-08-16 11:30:00         0  54051  prediction               0
#
#        sensor_0_avg  sensor_1_avg  sensor_2_avg  wind_speed_3_avg  \
# 54051          29.0          64.3         -28.6               4.7
#
#        wind_speed_4_avg  ...  sensor_47  sensor_48  sensor_49  sensor_50  \
# 54051               4.7  ...        0.0   -18275.0        0.0    22771.0
#
#        sensor_51  sensor_52_avg  sensor_52_max  sensor_52_min  sensor_52_std  \
# 54051   -18275.0           11.1           12.1           10.8            0.2
#
#        sensor_53_avg
# 54051           36.0
#
# [1 rows x 86 columns]
# DataFrame for 84 contains null values in the following rows:
#                 time_stamp  asset_id     id train_test  status_type_id  \
# 49871  2022-08-16 12:20:00        13  49871      train               0
#
#        sensor_0_avg  sensor_1_avg  sensor_2_avg  wind_speed_3_avg  \
# 49871          30.0         148.6          21.5               6.5
#
#        wind_speed_4_avg  ...  sensor_47  sensor_48  sensor_49  sensor_50  \
# 49871               6.4  ...    -1088.0   -19047.0        0.0    44185.0
#
#        sensor_51  sensor_52_avg  sensor_52_max  sensor_52_min  sensor_52_std  \
# 49871   -20135.0            8.9           14.1            0.0            5.5
#
#        sensor_53_avg
# 49871           34.0
#
# [1 rows x 86 columns]
# DataFrame for 92 does not contain any null values.
# DataFrame for 3 contains null values in the following rows:
#                 time_stamp  asset_id     id train_test  status_type_id  \
# 38779  2020-01-23 19:00:00        10  38779      train               5
# 38780  2020-01-23 19:40:00        10  38780      train               5
#
#        sensor_0_avg  sensor_1_avg  sensor_2_avg  wind_speed_3_avg  \
# 38779          12.0         301.1           2.6               3.5
# 38780          11.0         283.9          -9.0               4.0
#
#        wind_speed_4_avg  ...  sensor_47  sensor_48  sensor_49  sensor_50  \
# 38779               3.5  ...     -635.0     -270.0        0.0    -1043.0
# 38780               3.7  ...     -510.0        3.0        0.0     -180.0
#
#        sensor_51  sensor_52_avg  sensor_52_max  sensor_52_min  sensor_52_std  \
# 38779     -905.0            5.4           13.0            0.0            4.6
# 38780     -507.0            5.1           12.7            0.0            4.3
#
#        sensor_53_avg
# 38779           16.0
# 38780           15.0
#
# [2 rows x 86 columns]
# DataFrame for 45 does not contain any null values.
# DataFrame for 22 contains null values in the following rows:
#                 time_stamp  asset_id     id  train_test  status_type_id  \
# 52618  2021-08-16 11:30:00        21  52618  prediction               0
#
#        sensor_0_avg  sensor_1_avg  sensor_2_avg  wind_speed_3_avg  \
# 52618          29.0         110.1          12.0               4.3
#
#        wind_speed_4_avg  ...  sensor_47  sensor_48  sensor_49  sensor_50  \
# 52618               4.3  ...     -205.0   -10478.0        0.0    17146.0
#
#        sensor_51  sensor_52_avg  sensor_52_max  sensor_52_min  sensor_52_std  \
# 52618   -10682.0           11.1           11.6           10.9            0.1
#
#        sensor_53_avg
# 52618           34.0
#
# [1 rows x 86 columns]
# DataFrame for 25 does not contain any null values.
# DataFrame for 24 does not contain any null values.
# DataFrame for 26 contains null values in the following rows:
#                 time_stamp  asset_id     id train_test  status_type_id  \
# 44279  2020-08-16 11:30:00         0  44279      train               5
#
#        sensor_0_avg  sensor_1_avg  sensor_2_avg  wind_speed_3_avg  \
# 44279          29.0          64.3         -28.6               4.7
#
#        wind_speed_4_avg  ...  sensor_47  sensor_48  sensor_49  sensor_50  \
# 44279               4.7  ...        0.0   -18275.0        0.0    22771.0
#
#        sensor_51  sensor_52_avg  sensor_52_max  sensor_52_min  sensor_52_std  \
# 44279   -18275.0           11.1           12.1           10.8            0.2
#
#        sensor_53_avg
# 44279           36.0
#
# [1 rows x 86 columns]
# DataFrame for 17 contains null values in the following rows:
#                 time_stamp  asset_id     id train_test  status_type_id  \
# 12090  2015-01-24 19:00:00        10  12090      train               5
# 12091  2015-01-24 19:40:00        10  12091      train               5
# 41524  2015-08-18 12:20:00        10  41524      train               0
#
#        sensor_0_avg  sensor_1_avg  sensor_2_avg  wind_speed_3_avg  \
# 12090          12.0         301.1           2.6               3.5
# 12091          11.0         283.9          -9.0               4.0
# 41524          30.0         175.7          43.1               6.4
#
#        wind_speed_4_avg  ...  sensor_47  sensor_48  sensor_49  sensor_50  \
# 12090               3.5  ...     -635.0     -270.0        0.0    -1043.0
# 12091               3.7  ...     -510.0        3.0        0.0     -180.0
# 41524               6.2  ...     -834.0   -18886.0        0.0    49351.0
#
#        sensor_51  sensor_52_avg  sensor_52_max  sensor_52_min  sensor_52_std  \
# 12090     -905.0            5.4           13.0            0.0            4.6
# 12091     -507.0            5.1           12.7            0.0            4.3
# 41524   -19720.0            9.1           14.5            0.0            5.8
#
#        sensor_53_avg
# 12090           16.0
# 12091           15.0
# 41524           36.0
#
# [3 rows x 86 columns]
# DataFrame for 14 does not contain any null values.
# DataFrame for 10 contains null values in the following rows:
#                 time_stamp  asset_id     id train_test  status_type_id  \
# 15284  2014-01-24 19:00:00        10  15284      train               5
# 15285  2014-01-24 19:40:00        10  15285      train               5
# 44718  2014-08-18 12:20:00        10  44718      train               0
#
#        sensor_0_avg  sensor_1_avg  sensor_2_avg  wind_speed_3_avg  \
# 15284          12.0         301.1           2.6               3.5
# 15285          11.0         283.9          -9.0               4.0
# 44718          30.0         175.7          43.1               6.4
#
#        wind_speed_4_avg  ...  sensor_47  sensor_48  sensor_49  sensor_50  \
# 15284               3.5  ...     -635.0     -270.0        0.0    -1043.0
# 15285               3.7  ...     -510.0        3.0        0.0     -180.0
# 44718               6.2  ...     -834.0   -18886.0        0.0    49351.0
#
#        sensor_51  sensor_52_avg  sensor_52_max  sensor_52_min  sensor_52_std  \
# 15284     -905.0            5.4           13.0            0.0            4.6
# 15285     -507.0            5.1           12.7            0.0            4.3
# 44718   -19720.0            9.1           14.5            0.0            5.8
#
#        sensor_53_avg
# 15284           16.0
# 15285           15.0
# 44718           36.0
#
# [3 rows x 86 columns]
# DataFrame for 38 does not contain any null values.
# DataFrame for 13 does not contain any null values.
# DataFrame for 73 does not contain any null values.
# DataFrame for 72 contains null values in the following rows:
#                 time_stamp  asset_id     id train_test  status_type_id  \
# 44751  2021-08-16 11:30:00        21  44751      train               5
#
#        sensor_0_avg  sensor_1_avg  sensor_2_avg  wind_speed_3_avg  \
# 44751          29.0         110.1          12.0               4.3
#
#        wind_speed_4_avg  ...  sensor_47  sensor_48  sensor_49  sensor_50  \
# 44751               4.3  ...     -205.0   -10478.0        0.0    17146.0
#
#        sensor_51  sensor_52_avg  sensor_52_max  sensor_52_min  sensor_52_std  \
# 44751   -10682.0           11.1           11.6           10.9            0.1
#
#        sensor_53_avg
# 44751           34.0
#
# [1 rows x 86 columns]
# DataFrame for 71 does not contain any null values.

# %%
#Drop rows with null values

for key, df in dataframes.items():
    dataframes[key] = df.dropna()
    print(f"Dropped null rows from DataFrame for {key}. New shape: {dataframes[key].shape}")
# Out:
# Dropped null rows from DataFrame for 68. New shape: (54358, 86)
# Dropped null rows from DataFrame for 40. New shape: (56156, 86)
# Dropped null rows from DataFrame for 69. New shape: (54812, 86)
# Dropped null rows from DataFrame for 42. New shape: (53883, 86)
# Dropped null rows from DataFrame for 0. New shape: (54985, 86)
# Dropped null rows from DataFrame for 84. New shape: (53771, 86)
# Dropped null rows from DataFrame for 92. New shape: (54067, 86)
# Dropped null rows from DataFrame for 3. New shape: (55485, 86)
# Dropped null rows from DataFrame for 45. New shape: (53739, 86)
# Dropped null rows from DataFrame for 22. New shape: (53035, 86)
# Dropped null rows from DataFrame for 25. New shape: (54712, 86)
# Dropped null rows from DataFrame for 24. New shape: (55003, 86)
# Dropped null rows from DataFrame for 26. New shape: (53701, 86)
# Dropped null rows from DataFrame for 17. New shape: (55087, 86)
# Dropped null rows from DataFrame for 14. New shape: (54197, 86)
# Dropped null rows from DataFrame for 10. New shape: (53589, 86)
# Dropped null rows from DataFrame for 38. New shape: (54835, 86)
# Dropped null rows from DataFrame for 13. New shape: (54010, 86)
# Dropped null rows from DataFrame for 73. New shape: (54042, 86)
# Dropped null rows from DataFrame for 72. New shape: (54081, 86)
# Dropped null rows from DataFrame for 71. New shape: (54744, 86)

# %%
# Iterate over the dataframes dictionary
for key, df in dataframes.items():
    # Check if the column "train_test" exists in the DataFrame
    if "train_test" in df.columns:
        # Drop the column "train_test" from the DataFrame
        dataframes[key] = df.drop(columns=["train_test"])

        # Optionally, print information about the dropped column
        print(f"Dropped column 'train_test' from DataFrame for {key}. New shape: {dataframes[key].shape}")
    else:
        # Optionally, print a message if the column doesn't exist
        print(f"DataFrame for {key} does not contain a column named 'train_test'.")
# Out:
# Dropped column 'train_test' from DataFrame for 68. New shape: (54358, 85)
# Dropped column 'train_test' from DataFrame for 40. New shape: (56156, 85)
# Dropped column 'train_test' from DataFrame for 69. New shape: (54812, 85)
# Dropped column 'train_test' from DataFrame for 42. New shape: (53883, 85)
# Dropped column 'train_test' from DataFrame for 0. New shape: (54985, 85)
# Dropped column 'train_test' from DataFrame for 84. New shape: (53771, 85)
# Dropped column 'train_test' from DataFrame for 92. New shape: (54067, 85)
# Dropped column 'train_test' from DataFrame for 3. New shape: (55485, 85)
# Dropped column 'train_test' from DataFrame for 45. New shape: (53739, 85)
# Dropped column 'train_test' from DataFrame for 22. New shape: (53035, 85)
# Dropped column 'train_test' from DataFrame for 25. New shape: (54712, 85)
# Dropped column 'train_test' from DataFrame for 24. New shape: (55003, 85)
# Dropped column 'train_test' from DataFrame for 26. New shape: (53701, 85)
# Dropped column 'train_test' from DataFrame for 17. New shape: (55087, 85)
# Dropped column 'train_test' from DataFrame for 14. New shape: (54197, 85)
# Dropped column 'train_test' from DataFrame for 10. New shape: (53589, 85)
# Dropped column 'train_test' from DataFrame for 38. New shape: (54835, 85)
# Dropped column 'train_test' from DataFrame for 13. New shape: (54010, 85)
# Dropped column 'train_test' from DataFrame for 73. New shape: (54042, 85)
# Dropped column 'train_test' from DataFrame for 72. New shape: (54081, 85)
# Dropped column 'train_test' from DataFrame for 71. New shape: (54744, 85)

# %%
# Iterate over the dataframes dictionary
for key, df in dataframes.items():
    # Check if the column "train_test" exists in the DataFrame
    if "id" in df.columns:
        # Drop the column "train_test" from the DataFrame
        dataframes[key] = df.drop(columns=["id"])

        # Optionally, print information about the dropped column
        print(f"Dropped column 'id' from DataFrame for {key}. New shape: {dataframes[key].shape}")
    else:
        # Optionally, print a message if the column doesn't exist
        print(f"DataFrame for {key} does not contain a column named 'id'.")
# Out:
# Dropped column 'id' from DataFrame for 68. New shape: (54358, 84)
# Dropped column 'id' from DataFrame for 40. New shape: (56156, 84)
# Dropped column 'id' from DataFrame for 69. New shape: (54812, 84)
# Dropped column 'id' from DataFrame for 42. New shape: (53883, 84)
# Dropped column 'id' from DataFrame for 0. New shape: (54985, 84)
# Dropped column 'id' from DataFrame for 84. New shape: (53771, 84)
# Dropped column 'id' from DataFrame for 92. New shape: (54067, 84)
# Dropped column 'id' from DataFrame for 3. New shape: (55485, 84)
# Dropped column 'id' from DataFrame for 45. New shape: (53739, 84)
# Dropped column 'id' from DataFrame for 22. New shape: (53035, 84)
# Dropped column 'id' from DataFrame for 25. New shape: (54712, 84)
# Dropped column 'id' from DataFrame for 24. New shape: (55003, 84)
# Dropped column 'id' from DataFrame for 26. New shape: (53701, 84)
# Dropped column 'id' from DataFrame for 17. New shape: (55087, 84)
# Dropped column 'id' from DataFrame for 14. New shape: (54197, 84)
# Dropped column 'id' from DataFrame for 10. New shape: (53589, 84)
# Dropped column 'id' from DataFrame for 38. New shape: (54835, 84)
# Dropped column 'id' from DataFrame for 13. New shape: (54010, 84)
# Dropped column 'id' from DataFrame for 73. New shape: (54042, 84)
# Dropped column 'id' from DataFrame for 72. New shape: (54081, 84)
# Dropped column 'id' from DataFrame for 71. New shape: (54744, 84)

# %%
output_directory = "Wind_Farm_B_Clean"

# Loop through the dataframes dictionary and export each DataFrame to a CSV file

for key, df in dataframes.items():
    # Create the full file path
    file_path = os.path.join(output_directory, f'{key}.csv')
    
    # Export the DataFrame to a CSV file
    df.to_csv(file_path, index=False, sep=',')

    # Optionally, print a message indicating the export was successful
    print(f'Exported {key} to {file_path}')
# Out:
# Exported 68 to Wind_Farm_B_Clean/68.csv
# Exported 40 to Wind_Farm_B_Clean/40.csv
# Exported 69 to Wind_Farm_B_Clean/69.csv
# Exported 42 to Wind_Farm_B_Clean/42.csv
# Exported 0 to Wind_Farm_B_Clean/0.csv
# Exported 84 to Wind_Farm_B_Clean/84.csv
# Exported 92 to Wind_Farm_B_Clean/92.csv
# Exported 3 to Wind_Farm_B_Clean/3.csv
# Exported 45 to Wind_Farm_B_Clean/45.csv
# Exported 22 to Wind_Farm_B_Clean/22.csv
# Exported 25 to Wind_Farm_B_Clean/25.csv
# Exported 24 to Wind_Farm_B_Clean/24.csv
# Exported 26 to Wind_Farm_B_Clean/26.csv
# Exported 17 to Wind_Farm_B_Clean/17.csv
# Exported 14 to Wind_Farm_B_Clean/14.csv
# Exported 10 to Wind_Farm_B_Clean/10.csv
# Exported 38 to Wind_Farm_B_Clean/38.csv
# Exported 13 to Wind_Farm_B_Clean/13.csv
# Exported 73 to Wind_Farm_B_Clean/73.csv
# Exported 72 to Wind_Farm_B_Clean/72.csv
# Exported 71 to Wind_Farm_B_Clean/71.csv
